# %% [markdown]
# <a href="https://colab.research.google.com/github/silmarildust/SIP-2024/blob/main/fig1summaries.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_excel("/content/GRAB APP AND API DATA.xlsx", skiprows=13)

sns.boxplot(x='Route (API)', y='Surge factor', data=df, flierprops={'marker':'o', 'markerfacecolor':'green', 'markersize':5})
plt.show()

# %%
df.groupby('Route (API)')['Surge factor'].describe()
# Out:
#              count      mean       std       min       25%       50%  \
# Route (API)
# 1            133.0  1.421787  0.064878  1.242347  1.388327  1.422241
# 2            132.0  1.431952  0.091520  1.183068  1.409174  1.454491
# 3            133.0  1.376293  0.091369  1.199699  1.319217  1.352542
# 5            132.0  1.477018  0.124177  1.250750  1.382385  1.424747
# 6            133.0  1.349442  0.044392  1.148325  1.325153  1.354839
# 9            133.0  1.404762  0.034500  1.313156  1.383351  1.404660
# 10           133.0  1.370404  0.057884  1.230645  1.339337  1.364623
# 11           133.0  1.452884  0.107444  1.311379  1.377041  1.402738
# 12           133.0  1.483956  0.076624  1.265102  1.450545  1.480325
# 15           133.0  1.461972  0.049754  1.322352  1.429271  1.459353
#
#                   75%       max
# Route (API)
# 1            1.459789  1.623209
# 2            1.482698  1.665120
# 3            1.402290  1.657941
# 5            1.573685  1.773083
# ...
